# %%
import pandas as pd
import requests

# %%
endpoint_2023 = 'https://api.census.gov/data/2023/acs/acs1?get=NAME,B19013_001E,B06009_002E,B06009_003E,B06009_004E,B06009_005E,B06009_006E,B01003_001E&for=county:*&in=state:47'

response_2023 = requests.get(endpoint_2023)

# %%
response_2023
# Out:
# <Response [200]>

# %%
response_2023.text
# Out:
# '[["NAME","B19013_001E","B06009_002E","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B01003_001E","state","county"],\n["Anderson County, Tennessee","57652","6110","17825","16459","11112","5902","80234","47","001"],\n["Blount County, Tennessee","78504","9139","34234","29395","18912","11258","141456","47","009"],\n["Bradley County, Tennessee","61107","8202","25314","24902","11085","7552","111579","47","011"],\n["Davidson County, Tennessee","80379","41728","95843","105890","155280","98612","712334","47","037"],\n["Greene County, Tennessee","54261","7903","20142","16446","6143","2639","72577","47","059"],\n["Hamblen County, Tennessee","53210","5963","17335","13388","6599","4322","66216","47","063"],\n["Hamilton County, Tennessee","73611","20890","63023","83310","60297","40689","379864","47","065"],\n["Knox County, Tennessee","70265","25678","81801","87742","83512","57827","500669","47","093"],\n["Madison County, Tennessee","58702","7429","25160","19466","10109","5991","99193","
# ...

# %%
response_2023 = response_2023.json()

# %%
acs_2023 = pd.DataFrame(response_2023)

# %%
endpoint_2018 = 'https://api.census.gov/data/2018/acs/acs1?get=NAME,B19013_001E,B06009_002E,B06009_003E,B06009_004E,B06009_005E,B06009_006E,B01003_001E&for=county:*&in=state:47'

response_2018 = requests.get(endpoint_2018)

# %%
response_2018
# Out:
# <Response [200]>

# %%
response_2018.text
# Out:
# '[["NAME","B19013_001E","B06009_002E","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B01003_001E","state","county"],\n["Shelby County, Tennessee","47500","73241","175622","173268","116356","77628","935764","47","157"],\n["Davidson County, Tennessee","60856","50850","108339","118525","124607","78986","692587","47","037"],\n["Montgomery County, Tennessee","56019","7201","35280","46119","26479","12702","205950","47","125"],\n["Hamilton County, Tennessee","57280","26858","62509","86859","50319","29506","364286","47","065"],\n["Sullivan County, Tennessee","44652","12683","38303","35612","18515","9511","157668","47","163"],\n["Robertson County, Tennessee","69079","5724","17803","14977","7123","2682","71012","47","147"],\n["Blount County, Tennessee","58809","9545","32709","28242","14340","8537","131349","47","009"],\n["Madison County, Tennessee","45360","8253","21152","19863","10264","6138","97605","47","113"],\n["Williamson County, Tennessee","110700","6206","18884","31473","6126
# ...

# %%
response_2018 = response_2018.json()

# %%
acs_2018 = pd.DataFrame(response_2018)

# %%
endpoint_2013 = 'https://api.census.gov/data/2013/acs/acs1?get=NAME,B19013_001E,B06009_002E,B06009_003E,B06009_004E,B06009_005E,B06009_006E,B01003_001E&for=county:*&in=state:47'

response_2013 = requests.get(endpoint_2013)

# %%
response_2013
# Out:
# <Response [200]>

# %%
response_2013.text
# Out:
# '[["NAME","B19013_001E","B06009_002E","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B01003_001E","state","county"],\n["Washington County, Tennessee","41349","9015","27076","23018","14338","12459","125546","47","179"],\n["Maury County, Tennessee","45712","6545","21010","18104","8003","3393","83761","47","119"],\n["Robertson County, Tennessee","50510","6948","17531","11585","6095","2595","67383","47","147"],\n["Blount County, Tennessee","44351","11714","32915","24608","11688","6349","125099","47","009"],\n["Madison County, Tennessee","39523","7319","19871","20194","11325","5910","98733","47","113"],\n["Williamson County, Tennessee","88759","4869","21031","28627","46209","26217","198901","47","187"],\n["Greene County, Tennessee","35981","9380","19363","12201","4899","2894","68267","47","059"],\n["Putnam County, Tennessee","31448","6501","18374","11424","6773","3480","73525","47","141"],\n["Sevier County, Tennessee","40715","10865","23870","18320","7687","4221","93570","47","1
# ...

# %%
response_2013 = response_2013.json()

# %%
acs_2013 = pd.DataFrame(response_2013)

# %%
endpoint_2008 = 'https://api.census.gov/data/2008/acs/acs1?get=NAME,B19013_001E,B06009_002E,B06009_003E,B06009_004E,B06009_005E,B06009_006E,B01003_001E&for=county:*&in=state:47'

response_2008 = requests.get(endpoint_2008)

# %%
response_2008
# Out:
# <Response [200]>

# %%
response_2008.text
# Out:
# '[["NAME","B19013_001E","B06009_002E","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B01003_001E","state","county"],\n["Anderson County, Tennessee","45015","8646","18797","14624","7331","4055","74169","47","001"],\n["Blount County, Tennessee","47215","12246","28839","26481","11643","5486","121511","47","009"],\n["Bradley County, Tennessee","39948","13673","18966","20860","6822","4920","96472","47","011"],\n["Davidson County, Tennessee","46153","64540","107545","112131","84868","51052","626144","47","037"],\n["Greene County, Tennessee","35062","10225","20008","11125","4698","2724","66911","47","059"],\n["Hamilton County, Tennessee","47779","28825","62666","70735","43107","21275","332848","47","065"],\n["Knox County, Tennessee","45673","32233","76930","79108","64478","35158","430019","47","093"],\n["Madison County, Tennessee","43164","7985","19237","19844","9695","5044","96376","47","113"],\n["Maury County, Tennessee","46596","8454","20130","17662","6173","2263","81938","47",
# ...

# %%
response_2008 = response_2008.json()

# %%
acs_2008 = pd.DataFrame(response_2008)

# %% [markdown]
# acs_2023

# %%
acs_2023.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# 9    object
# dtype: object

# %%
acs_2023.columns = acs_2023.iloc[0]
acs_2023 = acs_2023[1:]

# %%
acs_2023 = acs_2023.drop(columns={'county', 'state'})

# %%
acs_2023 = acs_2023.rename(columns = {'NAME': 'county', 'B19013_001E': 'median_household_income', 'B06009_002E': 'less_than_high_school', 'B06009_003E': 'high_school', 'B06009_004E': 'some_college', 'B06009_005E': 'bachelors_degree', 'B06009_006E': 'graduate_degree', 'B01003_001E':'total_population'})

# %%
acs_2023.head(1)
# Out:
# 0                      county median_household_income less_than_high_school  \
# 1  Anderson County, Tennessee                   57652                  6110
#
# 0 high_school some_college bachelors_degree graduate_degree total_population
# 1       17825        16459            11112            5902            80234

# %%
acs_2023[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']] = acs_2023[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']].astype('int')

# %%
acs_2023
# Out:
# 0                         county  median_household_income  \
# 1     Anderson County, Tennessee                    57652
# 2       Blount County, Tennessee                    78504
# 3      Bradley County, Tennessee                    61107
# 4     Davidson County, Tennessee                    80379
# 5       Greene County, Tennessee                    54261
# 6      Hamblen County, Tennessee                    53210
# 7     Hamilton County, Tennessee                    73611
# 8         Knox County, Tennessee                    70265
# 9      Madison County, Tennessee                    58702
# 10       Maury County, Tennessee                    72651
# 11  Montgomery County, Tennessee                    75361
# 12      Putnam County, Tennessee                    56368
# 13   Robertson County, Tennessee                    83355
# 14  Rutherford County, Tennessee                    81628
# 15      Sevier County, Tennessee                    59665
# ...

# %%
acs_2023.dtypes
# Out:
# 0
# county                     object
# median_household_income     int64
# less_than_high_school       int64
# high_school                 int64
# some_college                int64
# bachelors_degree            int64
# graduate_degree             int64
# total_population            int64
# dtype: object

# %%
acs_2023.county = acs_2023.county.astype('str')

# %%
acs_2023.dtypes
# Out:
# 0
# county                     object
# median_household_income     int64
# less_than_high_school       int64
# high_school                 int64
# some_college                int64
# bachelors_degree            int64
# graduate_degree             int64
# total_population            int64
# dtype: object

# %%
acs_2023.county = acs_2023.county.str.replace(', Tennessee', '')

# %%
acs_2023['year'] = 2023

# %%
acs_2023.head(1)
# Out:
# 0           county  median_household_income  less_than_high_school  \
# 1  Anderson County                    57652                   6110
#
# 0  high_school  some_college  bachelors_degree  graduate_degree  \
# 1        17825         16459             11112             5902
#
# 0  total_population  year
# 1             80234  2023

# %%
acs_2023 = acs_2023[['year', 'county', 'median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']]

# %%
acs_2023
# Out:
# 0   year             county  median_household_income  less_than_high_school  \
# 1   2023    Anderson County                    57652                   6110
# 2   2023      Blount County                    78504                   9139
# 3   2023     Bradley County                    61107                   8202
# 4   2023    Davidson County                    80379                  41728
# 5   2023      Greene County                    54261                   7903
# 6   2023     Hamblen County                    53210                   5963
# 7   2023    Hamilton County                    73611                  20890
# 8   2023        Knox County                    70265                  25678
# 9   2023     Madison County                    58702                   7429
# 10  2023       Maury County                    72651                   4414
# 11  2023  Montgomery County                    75361                  10516
# ...

# %% [markdown]
# acs_2018

# %%
acs_2018
# Out:
#                                0            1            2            3  \
# 0                           NAME  B19013_001E  B06009_002E  B06009_003E
# 1       Shelby County, Tennessee        47500        73241       175622
# 2     Davidson County, Tennessee        60856        50850       108339
# 3   Montgomery County, Tennessee        56019         7201        35280
# 4     Hamilton County, Tennessee        57280        26858        62509
# 5     Sullivan County, Tennessee        44652        12683        38303
# 6    Robertson County, Tennessee        69079         5724        17803
# 7       Blount County, Tennessee        58809         9545        32709
# 8      Madison County, Tennessee        45360         8253        21152
# 9   Williamson County, Tennessee       110700         6206        18884
# 10      Greene County, Tennessee        47383         7505        19526
# 11      Putnam County, Tennessee        45199         5199        20615
# ...

# %%
acs_2018.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# 9    object
# dtype: object

# %%
acs_2018.columns = acs_2018.iloc[0]
acs_2018 = acs_2018[1:]

# %%
acs_2018 = acs_2018.drop(columns={'county', 'state'})

# %%
acs_2018 = acs_2018.rename(columns = {'NAME': 'county', 'B19013_001E': 'median_household_income', 'B06009_002E': 'less_than_high_school', 'B06009_003E': 'high_school', 'B06009_004E': 'some_college', 'B06009_005E': 'bachelors_degree', 'B06009_006E': 'graduate_degree', 'B01003_001E':'total_population'})

# %%
acs_2018[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']] = acs_2023[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']].astype('int')

# %%
acs_2018
# Out:
# 0                         county  median_household_income  \
# 1       Shelby County, Tennessee                    57652
# 2     Davidson County, Tennessee                    78504
# 3   Montgomery County, Tennessee                    61107
# 4     Hamilton County, Tennessee                    80379
# 5     Sullivan County, Tennessee                    54261
# 6    Robertson County, Tennessee                    53210
# 7       Blount County, Tennessee                    73611
# 8      Madison County, Tennessee                    70265
# 9   Williamson County, Tennessee                    58702
# 10      Greene County, Tennessee                    72651
# 11      Putnam County, Tennessee                    75361
# 12      Sevier County, Tennessee                    56368
# 13     Bradley County, Tennessee                    83355
# 14        Knox County, Tennessee                    81628
# 15    Anderson County, Tennessee                    59665
# ...

# %%
acs_2018.dtypes
# Out:
# 0
# county                     object
# median_household_income     int64
# less_than_high_school       int64
# high_school                 int64
# some_college                int64
# bachelors_degree            int64
# graduate_degree             int64
# total_population            int64
# dtype: object

# %%
acs_2018.county = acs_2018.county.astype('str')

# %%
acs_2018.dtypes
# Out:
# 0
# county                     object
# median_household_income     int64
# less_than_high_school       int64
# high_school                 int64
# some_college                int64
# bachelors_degree            int64
# graduate_degree             int64
# total_population            int64
# dtype: object

# %%
acs_2018.county = acs_2018.county.str.replace(', Tennessee', '')

# %%
acs_2018['year'] = 2018

# %%
acs_2018 = acs_2018[['year', 'county', 'median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']]

# %%
acs_2018
# Out:
# 0   year             county  median_household_income  less_than_high_school  \
# 1   2018      Shelby County                    57652                   6110
# 2   2018    Davidson County                    78504                   9139
# 3   2018  Montgomery County                    61107                   8202
# 4   2018    Hamilton County                    80379                  41728
# 5   2018    Sullivan County                    54261                   7903
# 6   2018   Robertson County                    53210                   5963
# 7   2018      Blount County                    73611                  20890
# 8   2018     Madison County                    70265                  25678
# 9   2018  Williamson County                    58702                   7429
# 10  2018      Greene County                    72651                   4414
# 11  2018      Putnam County                    75361                  10516
# ...

# %% [markdown]
# acs_2013

# %%
acs_2013
# Out:
#                                0            1            2            3  \
# 0                           NAME  B19013_001E  B06009_002E  B06009_003E
# 1   Washington County, Tennessee        41349         9015        27076
# 2        Maury County, Tennessee        45712         6545        21010
# 3    Robertson County, Tennessee        50510         6948        17531
# 4       Blount County, Tennessee        44351        11714        32915
# 5      Madison County, Tennessee        39523         7319        19871
# 6   Williamson County, Tennessee        88759         4869        21031
# 7       Greene County, Tennessee        35981         9380        19363
# 8       Putnam County, Tennessee        31448         6501        18374
# 9       Sevier County, Tennessee        40715        10865        23870
# 10     Bradley County, Tennessee        42722        11591        21504
# 11        Knox County, Tennessee        49165        25241        77695
# ...

# %%
acs_2013.columns = acs_2013.iloc[0]
acs_2013 = acs_2013[1:]

# %%
acs_2013 = acs_2013.drop(columns={'county', 'state'})

# %%
acs_2013 = acs_2013.rename(columns = {'NAME': 'county', 'B19013_001E': 'median_household_income', 'B06009_002E': 'less_than_high_school', 'B06009_003E': 'high_school', 'B06009_004E': 'some_college', 'B06009_005E': 'bachelors_degree', 'B06009_006E': 'graduate_degree', 'B01003_001E':'total_population'})

# %%
acs_2013[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']] = acs_2023[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']].astype('int')

# %%
acs_2013.county = acs_2013.county.astype('str')

# %%
acs_2013.dtypes
# Out:
# 0
# county                     object
# median_household_income     int64
# less_than_high_school       int64
# high_school                 int64
# some_college                int64
# bachelors_degree            int64
# graduate_degree             int64
# total_population            int64
# dtype: object

# %%
acs_2013.county = acs_2013.county.str.replace(', Tennessee', '')

# %%
acs_2013['year'] = 2013

# %%
acs_2013 = acs_2013[['year', 'county', 'median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']]

# %%
acs_2013
# Out:
# 0   year             county  median_household_income  less_than_high_school  \
# 1   2013  Washington County                    57652                   6110
# 2   2013       Maury County                    78504                   9139
# 3   2013   Robertson County                    61107                   8202
# 4   2013      Blount County                    80379                  41728
# 5   2013     Madison County                    54261                   7903
# 6   2013  Williamson County                    53210                   5963
# 7   2013      Greene County                    73611                  20890
# 8   2013      Putnam County                    70265                  25678
# 9   2013      Sevier County                    58702                   7429
# 10  2013     Bradley County                    72651                   4414
# 11  2013        Knox County                    75361                  10516
# ...

# %% [markdown]
# acs_2008

# %%
acs_2008
# Out:
#                                0            1            2            3  \
# 0                           NAME  B19013_001E  B06009_002E  B06009_003E
# 1     Anderson County, Tennessee        45015         8646        18797
# 2       Blount County, Tennessee        47215        12246        28839
# 3      Bradley County, Tennessee        39948        13673        18966
# 4     Davidson County, Tennessee        46153        64540       107545
# 5       Greene County, Tennessee        35062        10225        20008
# 6     Hamilton County, Tennessee        47779        28825        62666
# 7         Knox County, Tennessee        45673        32233        76930
# 8      Madison County, Tennessee        43164         7985        19237
# 9        Maury County, Tennessee        46596         8454        20130
# 10  Montgomery County, Tennessee        47136         8327        28393
# 11      Putnam County, Tennessee        35445         7815        17334
# ...

# %%
acs_2008.columns = acs_2008.iloc[0]
acs_2008 = acs_2008[1:]

# %%
acs_2008 = acs_2008.drop(columns={'county', 'state'})

# %%
acs_2008 = acs_2008.rename(columns = {'NAME': 'county', 'B19013_001E': 'median_household_income', 'B06009_002E': 'less_than_high_school', 'B06009_003E': 'high_school', 'B06009_004E': 'some_college', 'B06009_005E': 'bachelors_degree', 'B06009_006E': 'graduate_degree', 'B01003_001E':'total_population'})

# %%
acs_2008[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']] = acs_2023[['median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']].astype('int')

# %%
acs_2008.county = acs_2008.county.astype('str')

# %%
acs_2008.county = acs_2008.county.str.replace(', Tennessee', '')

# %%
acs_2008['year'] = 2008

# %%
acs_2008 = acs_2008[['year', 'county', 'median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']]

# %%
acs_2008
# Out:
# 0   year             county  median_household_income  less_than_high_school  \
# 1   2008    Anderson County                    57652                   6110
# 2   2008      Blount County                    78504                   9139
# 3   2008     Bradley County                    61107                   8202
# 4   2008    Davidson County                    80379                  41728
# 5   2008      Greene County                    54261                   7903
# 6   2008    Hamilton County                    53210                   5963
# 7   2008        Knox County                    73611                  20890
# 8   2008     Madison County                    70265                  25678
# 9   2008       Maury County                    58702                   7429
# 10  2008  Montgomery County                    72651                   4414
# 11  2008      Putnam County                    75361                  10516
# ...

# %%
acs_combined = pd.concat([acs_2023, acs_2018, acs_2013, acs_2008])

# %%
acs_combined.dtypes
# Out:
# 0
# year                        int64
# county                     object
# median_household_income     int64
# less_than_high_school       int64
# high_school                 int64
# some_college                int64
# bachelors_degree            int64
# graduate_degree             int64
# total_population            int64
# dtype: object

# %%
acs_combined['county'] = acs_combined['county'].astype('str')

# %%
acs_combined['county'] = acs_combined['county'].str.replace(' County', '')

# %%
acs_combined
# Out:
# 0   year      county  median_household_income  less_than_high_school  \
# 1   2023    Anderson                    57652                   6110
# 2   2023      Blount                    78504                   9139
# 3   2023     Bradley                    61107                   8202
# 4   2023    Davidson                    80379                  41728
# 5   2023      Greene                    54261                   7903
# ..   ...         ...                      ...                    ...
# 15  2008    Sullivan                    59665                   9517
# 16  2008      Sumner                    62413                  58126
# 17  2008  Washington                    56481                  11202
# 18  2008  Williamson                    86081                  11514
# 19  2008      Wilson                    60729                   8617
#
# 0   high_school  some_college  bachelors_degree  graduate_degree  \
# 1         17825         16459             11112             5902
# ...

# %%
acs_combined.to_csv('acs_combined.csv')

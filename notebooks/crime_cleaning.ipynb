# %%
import pandas as pd

# %%
crimes_2023 = pd.read_csv('../data/crime_2023.csv')

# %%
crimes_2023
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1186.0                   1858.0
# 1    Bledsoe                    42.0                     83.0
# 2     Blount                  2186.0                   1984.0
# 3    Bradley                  1741.0                   3003.0
# 4   Campbell                   229.0                    455.0
# ..       ...                     ...                      ...
# 90    Shelby                 43333.0                  89271.0
# 91   Stewart                    88.0                     90.0
# 92    Tipton                  1198.0                   1254.0
# 93     Wayne                   101.0                    116.0
# 94   Weakley                   335.0                    698.0
#
#     Crimes Against Society  Missing
# 0                   1199.0      NaN
# 1                     49.0      NaN
# 2                   1775.0      NaN
# 3                   2277.0      NaN
# ...

# %%
crimes_2018 = pd.read_csv('../data/crime_2018.csv')

# %%
crimes_2018
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1304.0                   2951.0
# 1    Bledsoe                    52.0                    173.0
# 2     Blount                  2182.0                   3204.0
# 3    Bradley                  2467.0                   5380.0
# 4   Campbell                   574.0                   1308.0
# ..       ...                     ...                      ...
# 90    Shelby                 42263.0                  72723.0
# 91   Stewart                   135.0                    232.0
# 92    Tipton                  1603.0                   1907.0
# 93     Wayne                    95.0                    182.0
# 94   Weakley                   339.0                    763.0
#
#     Crimes Against Society  Missing
# 0                   1162.0      NaN
# 1                     97.0      NaN
# 2                   1915.0      NaN
# 3                   3003.0      NaN
# ...

# %%
crimes_2013 = pd.read_csv('../data/crime_2013.csv')

# %%
crimes_2013
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1124.0                   3038.0
# 1    Bledsoe                    55.0                    188.0
# 2     Blount                  1588.0                   3890.0
# 3    Bradley                  1961.0                   5368.0
# 4   Campbell                   595.0                   1814.0
# ..       ...                     ...                      ...
# 90    Shelby                 44290.0                  71465.0
# 91   Stewart                   118.0                    318.0
# 92    Tipton                  1744.0                   2424.0
# 93     Wayne                   101.0                    227.0
# 94   Weakley                   446.0                    918.0
#
#     Crimes Against Society  Missing
# 0                    747.0      NaN
# 1                     70.0      NaN
# 2                    926.0      NaN
# 3                   1146.0      NaN
# ...

# %%
crimes_2008 = pd.read_csv('../data/crime_2008.csv')

# %%
crimes_2008
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1410.0                   4903.0
# 1    Bledsoe                    56.0                    148.0
# 2     Blount                  1867.0                   4705.0
# 3    Bradley                  2822.0                   5711.0
# 4   Campbell                  1201.0                   3174.0
# ..       ...                     ...                      ...
# 90    Shelby                 45076.0                  92909.0
# 91   Stewart                   205.0                    387.0
# 92    Tipton                  2004.0                   2686.0
# 93     Wayne                   141.0                    230.0
# 94   Weakley                   750.0                   1400.0
#
#     Crimes Against Society  Missing
# 0                    918.0      NaN
# 1                     25.0      NaN
# 2                   1204.0      NaN
# 3                    837.0      NaN
# ...

# %% [markdown]
# Clean - convert dtype of crimes to int

# %% [markdown]
# crime 2023

# %%
crimes_2023 = crimes_2023.drop(columns='Missing')

# %%
crimes_2023 = crimes_2023.rename(columns={'County': 'county', 'Crimes Against Persons': 'crimes_against_persons', 'Crimes Against Property': 'crimes_against_property', 'Crimes Against Society': 'crimes_against_society'})

# %%
crimes_2023.dtypes
# Out:
# county                      object
# crimes_against_persons     float64
# crimes_against_property    float64
# crimes_against_society     float64
# dtype: object

# %%
crimes_2023[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']] = crimes_2023[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']].astype('int')

# %%
crimes_2023
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1186                     1858
# 1    Bledsoe                      42                       83
# 2     Blount                    2186                     1984
# 3    Bradley                    1741                     3003
# 4   Campbell                     229                      455
# ..       ...                     ...                      ...
# 90    Shelby                   43333                    89271
# 91   Stewart                      88                       90
# 92    Tipton                    1198                     1254
# 93     Wayne                     101                      116
# 94   Weakley                     335                      698
#
#     crimes_against_society
# 0                     1199
# 1                       49
# 2                     1775
# 3                     2277
# 4                      433
# ..                     ...
# ...

# %% [markdown]
# crimes_2018

# %%
crimes_2018
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1304.0                   2951.0
# 1    Bledsoe                    52.0                    173.0
# 2     Blount                  2182.0                   3204.0
# 3    Bradley                  2467.0                   5380.0
# 4   Campbell                   574.0                   1308.0
# ..       ...                     ...                      ...
# 90    Shelby                 42263.0                  72723.0
# 91   Stewart                   135.0                    232.0
# 92    Tipton                  1603.0                   1907.0
# 93     Wayne                    95.0                    182.0
# 94   Weakley                   339.0                    763.0
#
#     Crimes Against Society  Missing
# 0                   1162.0      NaN
# 1                     97.0      NaN
# 2                   1915.0      NaN
# 3                   3003.0      NaN
# ...

# %%
crimes_2018 = crimes_2018.drop(columns='Missing')

# %%
crimes_2018 = crimes_2018.rename(columns={'County': 'county', 'Crimes Against Persons': 'crimes_against_persons', 'Crimes Against Property': 'crimes_against_property', 'Crimes Against Society': 'crimes_against_society'})

# %%
crimes_2018.dtypes
# Out:
# county                      object
# crimes_against_persons     float64
# crimes_against_property    float64
# crimes_against_society     float64
# dtype: object

# %%
crimes_2018
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                  1304.0                   2951.0
# 1    Bledsoe                    52.0                    173.0
# 2     Blount                  2182.0                   3204.0
# 3    Bradley                  2467.0                   5380.0
# 4   Campbell                   574.0                   1308.0
# ..       ...                     ...                      ...
# 90    Shelby                 42263.0                  72723.0
# 91   Stewart                   135.0                    232.0
# 92    Tipton                  1603.0                   1907.0
# 93     Wayne                    95.0                    182.0
# 94   Weakley                   339.0                    763.0
#
#     crimes_against_society
# 0                   1162.0
# 1                     97.0
# 2                   1915.0
# 3                   3003.0
# 4                    714.0
# ..                     ...
# ...

# %%
crimes_2018[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']] = crimes_2018[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']].astype('int')

# %%
crimes_2018
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1304                     2951
# 1    Bledsoe                      52                      173
# 2     Blount                    2182                     3204
# 3    Bradley                    2467                     5380
# 4   Campbell                     574                     1308
# ..       ...                     ...                      ...
# 90    Shelby                   42263                    72723
# 91   Stewart                     135                      232
# 92    Tipton                    1603                     1907
# 93     Wayne                      95                      182
# 94   Weakley                     339                      763
#
#     crimes_against_society
# 0                     1162
# 1                       97
# 2                     1915
# 3                     3003
# 4                      714
# ..                     ...
# ...

# %% [markdown]
# crimes_2013

# %%
crimes_2013
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1124.0                   3038.0
# 1    Bledsoe                    55.0                    188.0
# 2     Blount                  1588.0                   3890.0
# 3    Bradley                  1961.0                   5368.0
# 4   Campbell                   595.0                   1814.0
# ..       ...                     ...                      ...
# 90    Shelby                 44290.0                  71465.0
# 91   Stewart                   118.0                    318.0
# 92    Tipton                  1744.0                   2424.0
# 93     Wayne                   101.0                    227.0
# 94   Weakley                   446.0                    918.0
#
#     Crimes Against Society  Missing
# 0                    747.0      NaN
# 1                     70.0      NaN
# 2                    926.0      NaN
# 3                   1146.0      NaN
# ...

# %%
crimes_2013 = crimes_2013.drop(columns='Missing')

# %%
crimes_2013 = crimes_2013.rename(columns={'County': 'county', 'Crimes Against Persons': 'crimes_against_persons', 'Crimes Against Property': 'crimes_against_property', 'Crimes Against Society': 'crimes_against_society'})

# %%
crimes_2013.dtypes
# Out:
# county                      object
# crimes_against_persons     float64
# crimes_against_property    float64
# crimes_against_society     float64
# dtype: object

# %%
crimes_2013[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']] = crimes_2013[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']].astype('int')

# %%
crimes_2013.dtypes
# Out:
# county                     object
# crimes_against_persons      int32
# crimes_against_property     int32
# crimes_against_society      int32
# dtype: object

# %% [markdown]
# crimes_2008

# %%
crimes_2008
# Out:
#       County  Crimes Against Persons  Crimes Against Property  \
# 0   Anderson                  1410.0                   4903.0
# 1    Bledsoe                    56.0                    148.0
# 2     Blount                  1867.0                   4705.0
# 3    Bradley                  2822.0                   5711.0
# 4   Campbell                  1201.0                   3174.0
# ..       ...                     ...                      ...
# 90    Shelby                 45076.0                  92909.0
# 91   Stewart                   205.0                    387.0
# 92    Tipton                  2004.0                   2686.0
# 93     Wayne                   141.0                    230.0
# 94   Weakley                   750.0                   1400.0
#
#     Crimes Against Society  Missing
# 0                    918.0      NaN
# 1                     25.0      NaN
# 2                   1204.0      NaN
# 3                    837.0      NaN
# ...

# %%
crimes_2008 = crimes_2008.drop(columns='Missing')

# %%
crimes_2008 = crimes_2008.rename(columns={'County': 'county', 'Crimes Against Persons': 'crimes_against_persons', 'Crimes Against Property': 'crimes_against_property', 'Crimes Against Society': 'crimes_against_society'})

# %%
crimes_2008.dtypes
# Out:
# county                      object
# crimes_against_persons     float64
# crimes_against_property    float64
# crimes_against_society     float64
# dtype: object

# %%
crimes_2008[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']] = crimes_2008[['crimes_against_persons', 'crimes_against_property', 'crimes_against_society']].astype('int')

# %%
crimes_2008
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1410                     4903
# 1    Bledsoe                      56                      148
# 2     Blount                    1867                     4705
# 3    Bradley                    2822                     5711
# 4   Campbell                    1201                     3174
# ..       ...                     ...                      ...
# 90    Shelby                   45076                    92909
# 91   Stewart                     205                      387
# 92    Tipton                    2004                     2686
# 93     Wayne                     141                      230
# 94   Weakley                     750                     1400
#
#     crimes_against_society
# 0                      918
# 1                       25
# 2                     1204
# 3                      837
# 4                      397
# ..                     ...
# ...

# %% [markdown]
# crime_2023

# %%
crimes_2023['total_crimes'] = crimes_2023.crimes_against_persons + crimes_2023.crimes_against_property + crimes_2023.crimes_against_society

# %%
crimes_2023['year'] = 2023

# %%
crimes_2023['pct_crimes_against_persons'] = crimes_2023.crimes_against_persons/ crimes_2023.total_crimes*100
crimes_2023['pct_crimes_against_property'] = crimes_2023.crimes_against_property/ crimes_2023.total_crimes*100
crimes_2023['pct_crimes_against_society'] = crimes_2023.crimes_against_society/ crimes_2023.total_crimes*100
crimes_2023
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1186                     1858
# 1    Bledsoe                      42                       83
# 2     Blount                    2186                     1984
# 3    Bradley                    1741                     3003
# 4   Campbell                     229                      455
# ..       ...                     ...                      ...
# 90    Shelby                   43333                    89271
# 91   Stewart                      88                       90
# 92    Tipton                    1198                     1254
# 93     Wayne                     101                      116
# 94   Weakley                     335                      698
#
#     crimes_against_society  total_crimes  year  pct_crimes_against_persons  \
# 0                     1199          4243  2023                   27.951921
# ...

# %%
crimes_2023 = crimes_2023[['year', 'county', 'total_crimes', 'crimes_against_persons', 'pct_crimes_against_persons', 'crimes_against_property', 'pct_crimes_against_property', 'crimes_against_society', 'pct_crimes_against_society']]

# %%
crimes_2023
# Out:
#     year    county  total_crimes  crimes_against_persons  \
# 0   2023  Anderson          4243                    1186
# 1   2023   Bledsoe           174                      42
# 2   2023    Blount          5945                    2186
# 3   2023   Bradley          7021                    1741
# 4   2023  Campbell          1117                     229
# ..   ...       ...           ...                     ...
# 90  2023    Shelby        141909                   43333
# 91  2023   Stewart           495                      88
# 92  2023    Tipton          3364                    1198
# 93  2023     Wayne           328                     101
# 94  2023   Weakley          1478                     335
#
#     pct_crimes_against_persons  crimes_against_property  \
# 0                    27.951921                     1858
# 1                    24.137931                       83
# 2                    36.770395                     1984
# ...

# %% [markdown]
# crimes_2018

# %%
crimes_2018['total_crimes'] = crimes_2018.crimes_against_persons + crimes_2018.crimes_against_property + crimes_2018.crimes_against_society

# %%
crimes_2018['year'] = 2018

# %%
crimes_2018['pct_crimes_against_persons'] = crimes_2018.crimes_against_persons/ crimes_2018.total_crimes*100
crimes_2018['pct_crimes_against_property'] = crimes_2018.crimes_against_property/ crimes_2018.total_crimes*100
crimes_2018['pct_crimes_against_society'] = crimes_2018.crimes_against_society/ crimes_2018.total_crimes*100
crimes_2018
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1304                     2951
# 1    Bledsoe                      52                      173
# 2     Blount                    2182                     3204
# 3    Bradley                    2467                     5380
# 4   Campbell                     574                     1308
# ..       ...                     ...                      ...
# 90    Shelby                   42263                    72723
# 91   Stewart                     135                      232
# 92    Tipton                    1603                     1907
# 93     Wayne                      95                      182
# 94   Weakley                     339                      763
#
#     crimes_against_society  total_crimes  year  pct_crimes_against_persons  \
# 0                     1162          5417  2018                   24.072365
# ...

# %%
crimes_2018 = crimes_2018[['year', 'county', 'total_crimes', 'crimes_against_persons', 'pct_crimes_against_persons', 'crimes_against_property', 'pct_crimes_against_property', 'crimes_against_society', 'pct_crimes_against_society']]

# %%
crimes_2018
# Out:
#     year    county  total_crimes  crimes_against_persons  \
# 0   2018  Anderson          5417                    1304
# 1   2018   Bledsoe           322                      52
# 2   2018    Blount          7301                    2182
# 3   2018   Bradley         10850                    2467
# 4   2018  Campbell          2596                     574
# ..   ...       ...           ...                     ...
# 90  2018    Shelby        124137                   42263
# 91  2018   Stewart           561                     135
# 92  2018    Tipton          4431                    1603
# 93  2018     Wayne           399                      95
# 94  2018   Weakley          1502                     339
#
#     pct_crimes_against_persons  crimes_against_property  \
# 0                    24.072365                     2951
# 1                    16.149068                      173
# 2                    29.886317                     3204
# ...

# %% [markdown]
# crimes_2013

# %%
crimes_2013['total_crimes'] = crimes_2013.crimes_against_persons + crimes_2013.crimes_against_property + crimes_2013.crimes_against_society

# %%
crimes_2013['year'] = 2013

# %%
crimes_2013['pct_crimes_against_persons'] = crimes_2013.crimes_against_persons/ crimes_2013.total_crimes*100
crimes_2013['pct_crimes_against_property'] = crimes_2013.crimes_against_property/ crimes_2013.total_crimes*100
crimes_2013['pct_crimes_against_society'] = crimes_2013.crimes_against_society/ crimes_2013.total_crimes*100
crimes_2013
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1124                     3038
# 1    Bledsoe                      55                      188
# 2     Blount                    1588                     3890
# 3    Bradley                    1961                     5368
# 4   Campbell                     595                     1814
# ..       ...                     ...                      ...
# 90    Shelby                   44290                    71465
# 91   Stewart                     118                      318
# 92    Tipton                    1744                     2424
# 93     Wayne                     101                      227
# 94   Weakley                     446                      918
#
#     crimes_against_society  total_crimes  year  pct_crimes_against_persons  \
# 0                      747          4909  2013                   22.896720
# ...

# %%
crimes_2013 = crimes_2013[['year', 'county', 'total_crimes', 'crimes_against_persons', 'pct_crimes_against_persons', 'crimes_against_property', 'pct_crimes_against_property', 'crimes_against_society', 'pct_crimes_against_society']]

# %%
crimes_2013
# Out:
#     year    county  total_crimes  crimes_against_persons  \
# 0   2013  Anderson          4909                    1124
# 1   2013   Bledsoe           313                      55
# 2   2013    Blount          6404                    1588
# 3   2013   Bradley          8475                    1961
# 4   2013  Campbell          2971                     595
# ..   ...       ...           ...                     ...
# 90  2013    Shelby        126661                   44290
# 91  2013   Stewart           498                     118
# 92  2013    Tipton          4907                    1744
# 93  2013     Wayne           455                     101
# 94  2013   Weakley          1746                     446
#
#     pct_crimes_against_persons  crimes_against_property  \
# 0                    22.896720                     3038
# 1                    17.571885                      188
# 2                    24.797002                     3890
# ...

# %%
crimes_2013.dtypes
# Out:
# year                             int64
# county                          object
# total_crimes                     int32
# crimes_against_persons           int32
# pct_crimes_against_persons     float64
# crimes_against_property          int32
# pct_crimes_against_property    float64
# crimes_against_society           int32
# pct_crimes_against_society     float64
# dtype: object

# %% [markdown]
# crimes_2008

# %%
crimes_2008['total_crimes'] = crimes_2008.crimes_against_persons + crimes_2008.crimes_against_property + crimes_2008.crimes_against_society

# %%
crimes_2008['year'] = 2008

# %%
crimes_2008['pct_crimes_against_persons'] = crimes_2008.crimes_against_persons/ crimes_2008.total_crimes*100
crimes_2008['pct_crimes_against_property'] = crimes_2008.crimes_against_property/ crimes_2008.total_crimes*100
crimes_2008['pct_crimes_against_society'] = crimes_2008.crimes_against_society/ crimes_2008.total_crimes*100
crimes_2008
# Out:
#       county  crimes_against_persons  crimes_against_property  \
# 0   Anderson                    1410                     4903
# 1    Bledsoe                      56                      148
# 2     Blount                    1867                     4705
# 3    Bradley                    2822                     5711
# 4   Campbell                    1201                     3174
# ..       ...                     ...                      ...
# 90    Shelby                   45076                    92909
# 91   Stewart                     205                      387
# 92    Tipton                    2004                     2686
# 93     Wayne                     141                      230
# 94   Weakley                     750                     1400
#
#     crimes_against_society  total_crimes  year  pct_crimes_against_persons  \
# 0                      918          7231  2008                   19.499378
# ...

# %%
crimes_2008 = crimes_2008[['year', 'county', 'total_crimes', 'crimes_against_persons', 'pct_crimes_against_persons', 'crimes_against_property', 'pct_crimes_against_property', 'crimes_against_society', 'pct_crimes_against_society']]

# %%
crimes_2008
# Out:
#     year    county  total_crimes  crimes_against_persons  \
# 0   2008  Anderson          7231                    1410
# 1   2008   Bledsoe           229                      56
# 2   2008    Blount          7776                    1867
# 3   2008   Bradley          9370                    2822
# 4   2008  Campbell          4772                    1201
# ..   ...       ...           ...                     ...
# 90  2008    Shelby        149246                   45076
# 91  2008   Stewart           672                     205
# 92  2008    Tipton          5346                    2004
# 93  2008     Wayne           579                     141
# 94  2008   Weakley          2384                     750
#
#     pct_crimes_against_persons  crimes_against_property  \
# 0                    19.499378                     4903
# 1                    24.454148                      148
# 2                    24.009774                     4705
# ...

# %%
crimes_combined = pd.concat([crimes_2023, crimes_2018, crimes_2013, crimes_2008])

# %%
crimes_combined
# Out:
#     year    county  total_crimes  crimes_against_persons  \
# 0   2023  Anderson          4243                    1186
# 1   2023   Bledsoe           174                      42
# 2   2023    Blount          5945                    2186
# 3   2023   Bradley          7021                    1741
# 4   2023  Campbell          1117                     229
# ..   ...       ...           ...                     ...
# 90  2008    Shelby        149246                   45076
# 91  2008   Stewart           672                     205
# 92  2008    Tipton          5346                    2004
# 93  2008     Wayne           579                     141
# 94  2008   Weakley          2384                     750
#
#     pct_crimes_against_persons  crimes_against_property  \
# 0                    27.951921                     1858
# 1                    24.137931                       83
# 2                    36.770395                     1984
# ...

# %%
crimes_combined.to_csv('crimes_combined.csv')

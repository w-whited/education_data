# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
acs_cleaned = pd.read_csv('../data/acs_combined.csv')

# %%
acs_cleaned
# Out:
#     Unnamed: 0  year      county  median_household_income  \
# 0            1  2023    Anderson                    57652
# 1            2  2023      Blount                    78504
# 2            3  2023     Bradley                    61107
# 3            4  2023    Davidson                    80379
# 4            5  2023      Greene                    54261
# ..         ...   ...         ...                      ...
# 75          15  2008    Sullivan                    41296
# 76          16  2008      Sumner                    55167
# 77          17  2008  Washington                    43021
# 78          18  2008  Williamson                    93321
# 79          19  2008      Wilson                    57713
#
#     less_than_high_school  high_school  some_college  bachelors_degree  \
# 0                    6110        17825         16459             11112
# 1                    9139        34234         29395             18912
# 2                    8202        25314         24902             11085
# 3                   41728        95843        105890            155280
# 4                    7903        20142         16446              6143
# ..                    ...          ...           ...               ...
# 75                  18491        37337         32983             15174
# 76                  13885        31717         35425             17340
# 77                  11782        23082         22361             15648
# 78                   5508        22357         27773             38452
# 79                  11220        23043         19640             13320
#
#     graduate_degree  total_population
# 0              5902             80234
# 1             11258            141456
# 2              7552            111579
# 3             98612            712334
# 4              2639             72577
# ..              ...               ...
# 75             7673            153900
# 76             6359            155474
# 77             8411            118639
# 78            18977            171452
# 79             5718            109803
#
# [80 rows x 10 columns]

# %%
acs_cleaned = acs_cleaned[['year', 'county', 'median_household_income', 'less_than_high_school', 'high_school', 'some_college', 'bachelors_degree', 'graduate_degree', 'total_population']]

# %%
acs_cleaned
# Out:
#     year      county  median_household_income  less_than_high_school  \
# 0   2023    Anderson                    57652                   6110
# 1   2023      Blount                    78504                   9139
# 2   2023     Bradley                    61107                   8202
# 3   2023    Davidson                    80379                  41728
# 4   2023      Greene                    54261                   7903
# ..   ...         ...                      ...                    ...
# 75  2008    Sullivan                    41296                  18491
# 76  2008      Sumner                    55167                  13885
# 77  2008  Washington                    43021                  11782
# 78  2008  Williamson                    93321                   5508
# 79  2008      Wilson                    57713                  11220
#
#     high_school  some_college  bachelors_degree  graduate_degree  \
# 0         17825         16459             11112             5902
# 1         34234         29395             18912            11258
# 2         25314         24902             11085             7552
# 3         95843        105890            155280            98612
# 4         20142         16446              6143             2639
# ..          ...           ...               ...              ...
# 75        37337         32983             15174             7673
# 76        31717         35425             17340             6359
# 77        23082         22361             15648             8411
# 78        22357         27773             38452            18977
# 79        23043         19640             13320             5718
#
#     total_population
# 0              80234
# 1             141456
# 2             111579
# 3             712334
# 4              72577
# ..               ...
# 75            153900
# 76            155474
# 77            118639
# 78            171452
# 79            109803
#
# [80 rows x 9 columns]

# %%
crimes_cleaned = pd.read_csv('../data/crimes_combined.csv')

# %%
crimes_cleaned
# Out:
#      Unnamed: 0  year    county  total_crimes  crimes_against_persons  \
# 0             0  2023  Anderson          4243                    1186
# 1             1  2023   Bledsoe           174                      42
# 2             2  2023    Blount          5945                    2186
# 3             3  2023   Bradley          7021                    1741
# 4             4  2023  Campbell          1117                     229
# ..          ...   ...       ...           ...                     ...
# 375          90  2008    Shelby        149246                   45076
# 376          91  2008   Stewart           672                     205
# 377          92  2008    Tipton          5346                    2004
# 378          93  2008     Wayne           579                     141
# 379          94  2008   Weakley          2384                     750
#
#      pct_crimes_against_persons  crimes_against_property  \
# 0                     27.951921                     1858
# 1                     24.137931                       83
# 2                     36.770395                     1984
# 3                     24.797037                     3003
# 4                     20.501343                      455
# ..                          ...                      ...
# 375                   30.202484                    92909
# 376                   30.505952                      387
# 377                   37.485971                     2686
# 378                   24.352332                      230
# 379                   31.459732                     1400
#
#      pct_crimes_against_property  crimes_against_society  \
# 0                      43.789771                    1199
# 1                      47.701149                      49
# 2                      33.372582                    1775
# 3                      42.771685                    2277
# 4                      40.734109                     433
# ..                           ...                     ...
# 375                    62.252255                   11261
# 376                    57.589286                      80
# 377                    50.243172                     656
# 378                    39.723661                     208
# 379                    58.724832                     234
#
#      pct_crimes_against_society
# 0                     28.258308
# 1                     28.160920
# 2                     29.857023
# 3                     32.431278
# 4                     38.764548
# ..                          ...
# 375                    7.545261
# 376                   11.904762
# 377                   12.270857
# 378                   35.924007
# 379                    9.815436
#
# [380 rows x 10 columns]

# %%
crimes_cleaned = crimes_cleaned[['year', 'county', 'total_crimes', 'crimes_against_persons', 'pct_crimes_against_persons', 'crimes_against_property', 'pct_crimes_against_property', 'crimes_against_society', 'pct_crimes_against_society']]

# %%
crimes_cleaned
# Out:
#      year    county  total_crimes  crimes_against_persons  \
# 0    2023  Anderson          4243                    1186
# 1    2023   Bledsoe           174                      42
# 2    2023    Blount          5945                    2186
# 3    2023   Bradley          7021                    1741
# 4    2023  Campbell          1117                     229
# ..    ...       ...           ...                     ...
# 375  2008    Shelby        149246                   45076
# 376  2008   Stewart           672                     205
# 377  2008    Tipton          5346                    2004
# 378  2008     Wayne           579                     141
# 379  2008   Weakley          2384                     750
#
#      pct_crimes_against_persons  crimes_against_property  \
# 0                     27.951921                     1858
# 1                     24.137931                       83
# 2                     36.770395                     1984
# 3                     24.797037                     3003
# 4                     20.501343                      455
# ..                          ...                      ...
# 375                   30.202484                    92909
# 376                   30.505952                      387
# 377                   37.485971                     2686
# 378                   24.352332                      230
# 379                   31.459732                     1400
#
#      pct_crimes_against_property  crimes_against_society  \
# 0                      43.789771                    1199
# 1                      47.701149                      49
# 2                      33.372582                    1775
# 3                      42.771685                    2277
# 4                      40.734109                     433
# ..                           ...                     ...
# 375                    62.252255                   11261
# 376                    57.589286                      80
# 377                    50.243172                     656
# 378                    39.723661                     208
# 379                    58.724832                     234
#
#      pct_crimes_against_society
# 0                     28.258308
# 1                     28.160920
# 2                     29.857023
# 3                     32.431278
# 4                     38.764548
# ..                          ...
# 375                    7.545261
# 376                   11.904762
# 377                   12.270857
# 378                   35.924007
# 379                    9.815436
#
# [380 rows x 9 columns]

# %% [markdown]
# join tables

# %%
data_merged_df = pd.merge(crimes_cleaned, acs_cleaned, how = 'inner')

# %%
data_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   year                         80 non-null     int64
#  1   county                       80 non-null     object
#  2   total_crimes                 80 non-null     int64
#  3   crimes_against_persons       80 non-null     int64
#  4   pct_crimes_against_persons   80 non-null     float64
#  5   crimes_against_property      80 non-null     int64
#  6   pct_crimes_against_property  80 non-null     float64
#  7   crimes_against_society       80 non-null     int64
#  8   pct_crimes_against_society   80 non-null     float64
#  9   median_household_income      80 non-null     int64
#  10  less_than_high_school        80 non-null     int64
#  11  high_school                  80 non-null     int64
#  12  some_college                 80 non-null     int64
#  13  bachelors_degree             80 non-null     int64
#  14  graduate_degree              80 non-null     int64
#  15  total_population             80 non-null     int64
# dtypes: float64(3), int64(12), object(1)
# memory usage: 10.1+ KB

# %%
data_merged_df[['pct_crimes_against_persons', 'pct_crimes_against_property', 'pct_crimes_against_society']] = data_merged_df[['pct_crimes_against_persons', 'pct_crimes_against_property', 'pct_crimes_against_society']].astype('int')

# %%
data_merged_df['crime_rate_per_1000'] = data_merged_df['total_crimes']/ data_merged_df['total_population'] * 1000

# %%
data_merged_df
# Out:
#     year      county  total_crimes  crimes_against_persons  \
# 0   2023    Anderson          4243                    1186
# 1   2023      Blount          5945                    2186
# 2   2023     Bradley          7021                    1741
# 3   2023      Greene          4150                    1117
# 4   2023     Hamblen          5554                    1728
# ..   ...         ...           ...                     ...
# 75  2008  Williamson          5572                    1247
# 76  2008      Wilson          8571                    2432
# 77  2008     Madison         14278                    3866
# 78  2008  Montgomery         16342                    4286
# 79  2008      Shelby        149246                   45076
#
#     pct_crimes_against_persons  crimes_against_property  \
# 0                           27                     1858
# 1                           36                     1984
# 2                           24                     3003
# 3                           26                     1900
# 4                           31                     2404
# ..                         ...                      ...
# 75                          22                     3310
# 76                          28                     4981
# 77                          27                     9286
# 78                          26                    10190
# 79                          30                    92909
#
#     pct_crimes_against_property  crimes_against_society  \
# 0                            43                    1199
# 1                            33                    1775
# 2                            42                    2277
# 3                            45                    1133
# 4                            43                    1422
# ..                          ...                     ...
# 75                           59                    1015
# 76                           58                    1158
# 77                           65                    1126
# 78                           62                    1866
# 79                           62                   11261
#
#     pct_crimes_against_society  median_household_income  \
# 0                           28                    57652
# 1                           29                    78504
# 2                           32                    61107
# 3                           27                    54261
# 4                           25                    53210
# ..                         ...                      ...
# 75                          18                    93321
# 76                          13                    57713
# 77                           7                    43164
# 78                          11                    47136
# 79                           7                    45714
#
#     less_than_high_school  high_school  some_college  bachelors_degree  \
# 0                    6110        17825         16459             11112
# 1                    9139        34234         29395             18912
# 2                    8202        25314         24902             11085
# 3                    7903        20142         16446              6143
# 4                    5963        17335         13388              6599
# ..                    ...          ...           ...               ...
# 75                   5508        22357         27773             38452
# 76                  11220        23043         19640             13320
# 77                   7985        19237         19844              9695
# 78                   8327        28393         37035             13704
# 79                  85069       153760        173933            101564
#
#     graduate_degree  total_population  crime_rate_per_1000
# 0              5902             80234            52.882818
# 1             11258            141456            42.027203
# 2              7552            111579            62.924027
# 3              2639             72577            57.180650
# 4              4322             66216            83.877009
# ..              ...               ...                  ...
# 75            18977            171452            32.498892
# 76             5718            109803            78.057977
# 77             5044             96376           148.148917
# 78             7566            154756           105.598491
# 79            60114            906825           164.580818
#
# [80 rows x 17 columns]

# %%
data_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   year                         80 non-null     int64
#  1   county                       80 non-null     object
#  2   total_crimes                 80 non-null     int64
#  3   crimes_against_persons       80 non-null     int64
#  4   pct_crimes_against_persons   80 non-null     int64
#  5   crimes_against_property      80 non-null     int64
#  6   pct_crimes_against_property  80 non-null     int64
#  7   crimes_against_society       80 non-null     int64
#  8   pct_crimes_against_society   80 non-null     int64
#  9   median_household_income      80 non-null     int64
#  10  less_than_high_school        80 non-null     int64
#  11  high_school                  80 non-null     int64
#  12  some_college                 80 non-null     int64
#  13  bachelors_degree             80 non-null     int64
#  14  graduate_degree              80 non-null     int64
#  15  total_population             80 non-null     int64
#  16  crime_rate_per_1000          80 non-null     float64
# dtypes: float64(1), int64(15), object(1)
# memory usage: 10.8+ KB

# %%
data_merged_df.describe()
# Out:
#               year   total_crimes  crimes_against_persons  \
# count    80.000000      80.000000               80.000000
# mean   2015.687500   21986.262500             6148.100000
# std       5.622274   32631.865278            10097.326565
# min    2008.000000    2790.000000              920.000000
# 25%    2013.000000    6739.250000             1487.500000
# 50%    2018.000000    8961.000000             2430.500000
# 75%    2023.000000   18127.750000             4858.500000
# max    2023.000000  149246.000000            45076.000000
#
#        pct_crimes_against_persons  crimes_against_property  \
# count                   80.000000                80.000000
# mean                    26.075000             12446.737500
# std                      4.586096             19208.718321
# min                     18.000000               807.000000
# 25%                     22.750000              3288.000000
# 50%                     26.000000              4942.000000
# 75%                     30.000000             11002.500000
# max                     36.000000             92909.000000
#
#        pct_crimes_against_property  crimes_against_society  \
# count                    80.000000               80.000000
# mean                     53.825000             3391.425000
# std                       8.941122             4349.994054
# min                      28.000000              330.000000
# 25%                      47.000000             1142.750000
# 50%                      54.000000             1764.000000
# 75%                      61.250000             3478.500000
# max                      69.000000            23188.000000
#
#        pct_crimes_against_society  median_household_income  \
# count                   80.000000                80.000000
# mean                    18.637500             56616.300000
# std                      7.994054             17784.130208
# min                      6.000000             31448.000000
# 25%                     12.750000             45326.500000
# 50%                     18.000000             52113.500000
# 75%                     23.250000             60918.750000
# max                     42.000000            133990.000000
#
#        less_than_high_school    high_school   some_college  bachelors_degree  \
# count              80.000000      80.000000      80.000000         80.000000
# mean            16903.362500   42252.537500   43879.062500      30899.737500
# std             17810.985114   35949.893655   40498.040236      33886.203762
# min              4414.000000   16342.000000   11125.000000       4615.000000
# 25%              7486.000000   20691.500000   19179.500000       8190.500000
# 50%             10217.500000   27734.500000   27281.000000      15581.500000
# 75%             17283.000000   42780.750000   47177.000000      41619.000000
# max             85972.000000  175622.000000  178963.000000     155280.000000
#
#        graduate_degree  total_population  crime_rate_per_1000
# count        80.000000           80.0000            80.000000
# mean      18480.712500       227063.8875            80.098227
# std       22334.841981       221145.2898            31.215528
# min        2263.000000        66216.0000            28.878688
# 25%        5028.750000        94147.5000            57.045291
# 50%        8339.500000       134884.5000            75.747536
# 75%       21177.500000       253067.5000            94.627019
# max       98612.000000       939465.0000           164.580818

# %%
data_merged_df.isnull().sum()
# Out:
# year                           0
# county                         0
# total_crimes                   0
# crimes_against_persons         0
# pct_crimes_against_persons     0
# crimes_against_property        0
# pct_crimes_against_property    0
# crimes_against_society         0
# pct_crimes_against_society     0
# median_household_income        0
# less_than_high_school          0
# high_school                    0
# some_college                   0
# bachelors_degree               0
# graduate_degree                0
# total_population               0
# crime_rate_per_1000            0
# dtype: int64

# %% [markdown]
# plots

# %%
data_merged_df.hist();

# %%
data_merged_df.total_crimes.hist()
plt.title('Total Crimes');

# %%
data_merged_df.crime_rate_per_1000.hist()
plt.title('Crime Rate per 1000 people');

# %%
data_merged_df.boxplot(column = ['median_household_income']);

# %%
data_merged_df.sort_values('median_household_income', ascending = False)
# Out:
#     year      county  total_crimes  crimes_against_persons  \
# 16  2023  Williamson          7668                    2198
# 36  2018  Williamson          7258                    1443
# 17  2023      Wilson          6820                    1395
# 75  2008  Williamson          5572                    1247
# 56  2013  Williamson          5744                    1106
# ..   ...         ...           ...                     ...
# 58  2013     Madison         12196                    3822
# 44  2013      Greene          4081                     920
# 72  2008      Putnam          6686                    1495
# 64  2008      Greene          3973                     975
# 52  2013      Putnam          6157                    1244
#
#     pct_crimes_against_persons  crimes_against_property  \
# 16                          28                     3222
# 36                          19                     3430
# 17                          20                     2494
# 75                          22                     3310
# 56                          19                     3192
# ..                         ...                      ...
# 58                          31                     7171
# 44                          22                     2678
# 72                          22                     4510
# 64                          24                     2668
# 52                          20                     4111
#
#     pct_crimes_against_property  crimes_against_society  \
# 16                           42                    2248
# 36                           47                    2385
# 17                           36                    2931
# 75                           59                    1015
# 56                           55                    1446
# ..                          ...                     ...
# 58                           58                    1203
# 44                           65                     483
# 72                           67                     681
# 64                           67                     330
# 52                           66                     802
#
#     pct_crimes_against_society  median_household_income  \
# 16                          29                   133990
# 36                          32                   110700
# 17                          42                    96171
# 75                          18                    93321
# 56                          25                    88759
# ..                         ...                      ...
# 58                           9                    39523
# 44                          11                    35981
# 72                          10                    35445
# 64                           8                    35062
# 52                          13                    31448
#
#     less_than_high_school  high_school  some_college  bachelors_degree  \
# 16                   6794        21087         38059             65039
# 36                   6206        18884         31473             61268
# 17                   5859        32318         33923             28269
# 75                   5508        22357         27773             38452
# 56                   4869        21031         28627             46209
# ..                    ...          ...           ...               ...
# 58                   7319        19871         20194             11325
# 44                   9380        19363         12201              4899
# 72                   7815        17334         12145              4615
# 64                  10225        20008         11125              4698
# 52                   6501        18374         11424              6773
#
#     graduate_degree  total_population  crime_rate_per_1000
# 16            45030            264460            28.994933
# 36            33506            231729            31.321069
# 17            14522            163674            41.668194
# 75            18977            171452            32.498892
# 56            26217            198901            28.878688
# ..              ...               ...                  ...
# 58             5910             98733           123.525063
# 44             2894             68267            59.779982
# 72             2688             71160            93.957279
# 64             2724             66911            59.377382
# 52             3480             73525            83.740224
#
# [80 rows x 17 columns]
